# %%
import requests
from pprint import pprint

headers = {'User Agent':'Chrome/76.0.3809.100'}
link = 'https://api.github.com/users/sezgingure/repos'
req = requests.get(link)
json = req.json()
pprint(json)
# Out:
# [{'archive_url': 'https://api.github.com/repos/sezgingure/git-repo/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/sezgingure/git-repo/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/sezgingure/git-repo/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/sezgingure/git-repo/branches{/branch}',
#   'clone_url': 'https://github.com/sezgingure/git-repo.git',
#   'collaborators_url': 'https://api.github.com/repos/sezgingure/git-repo/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/sezgingure/git-repo/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/sezgingure/git-repo/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/sezgingure/git-repo/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/sezgingure/git-repo/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/sezgingure/git-repo/contributors',
# ...

# %%
for i in json:
    pprint (i['name'])
# Out:
# 'git-repo'
# 'StartupIdeas'

# %% [markdown]
# ### ДЗ 2

# %%
req = requests.get('https://api.login.yahoo.com/oauth2/request_auth?client_id=dj0yJmk9ZkJVTE1YTkFGbU1EJmQ9WVdrOWFqVjRRV1pLTXpZbWNHbzlNQS0tJnM9Y29uc3VtZXJzZWNyZXQmc3Y9MCZ4PWZj--&language=en-us')

json = req.json

print(json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
pprint(req.text)
# Out:
# ('<!DOCTYPE html>\n'
#  '<html id="Stencil" class="no-js mobile">\n'
#  '    <head>\n'
#  '        <meta charset="utf-8">\n'
#  '        <meta name="viewport" content="initial-scale=1, maximum-scale=1, '
#  'user-scalable=0"/>\n'
#  '        <meta name="format-detection" content="telephone=no">\n'
#  '        <meta name="referrer" content="origin-when-cross-origin">\n'
#  '        <title>Yahoo</title>\n'
#  '        <link rel="dns-prefetch" href="//gstatic.com">\n'
#  '        <link rel="dns-prefetch" href="//google.com">\n'
#  '        <link rel="dns-prefetch" href="//s.yimg.com">\n'
#  '        <link rel="dns-prefetch" href="//y.analytics.yahoo.com">\n'
#  '        <link rel="dns-prefetch" href="//ucs.query.yahoo.com">\n'
#  '        <link rel="dns-prefetch" href="//geo.query.yahoo.com">\n'
#  '        <link rel="dns-prefetch" href="//geo.yahoo.com">\n'
#  '        <link rel="icon" type="image/x-icon" '
#  'href="https://s.yimg.com/wm/login/favicon.ico">\n'
# ...
